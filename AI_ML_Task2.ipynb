# %% [markdown]
# # House Price Prediction Using Machine Learning

# %%
print("Hello Tanishka")
# Out:
# Hello Tanishka

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

print("All libraries working")
# Out:
# All libraries working

# %% [markdown]
# ## Dataset Loading

# %%
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()

print(housing.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
import pandas as pd

df = pd.DataFrame(
    housing.data,
    columns=housing.feature_names
)

df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
df.shape
# Out:
# (20640, 8)

# %%
df.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %%
df.shape
# Out:
# (20640, 8)

# %%
df.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude'],
#       dtype='str')

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(12,8))
plt.show()

# %%
df["HousePrice"] = housing.target

df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  HousePrice
# 0    -122.23       4.526
# 1    -122.22       3.585
# 2    -122.24       3.521
# 3    -122.25       3.413
# 4    -122.25       3.422

# %% [markdown]
# ### Observation
#
# The dataset contains 20,640 records and 8 features. No major missing values were observed. The features have different ranges, making feature scaling necessary.

# %% [markdown]
# ## Correlation Analysis

# %%
df.corr()["HousePrice"].sort_values(ascending=False)
# Out:
# HousePrice    1.000000
# MedInc        0.688075
# AveRooms      0.151948
# HouseAge      0.105623
# AveOccup     -0.023737
# Population   -0.024650
# Longitude    -0.045967
# AveBedrms    -0.046701
# Latitude     -0.144160
# Name: HousePrice, dtype: float64

# %% [markdown]
# ### Observation
#
# Median Income showed the strongest positive correlation with house prices, indicating that income is an important factor in determining housing prices.

# %% [markdown]
# ## Data Preprocessing

# %%
X = df.drop("HousePrice", axis=1)

y = df["HousePrice"]

# %%
print(X.head())
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Feature Scaling

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
print(X_scaled[:5])
# Out:
# [[ 2.34476576  0.98214266  0.62855945 -0.15375759 -0.9744286  -0.04959654
#    1.05254828 -1.32783522]
#  [ 2.33223796 -0.60701891  0.32704136 -0.26333577  0.86143887 -0.09251223
#    1.04318455 -1.32284391]
#  [ 1.7826994   1.85618152  1.15562047 -0.04901636 -0.82077735 -0.02584253
#    1.03850269 -1.33282653]
#  [ 0.93296751  1.85618152  0.15696608 -0.04983292 -0.76602806 -0.0503293
#    1.03850269 -1.33781784]
#  [-0.012881    1.85618152  0.3447108  -0.03290586 -0.75984669 -0.08561576
#    1.03850269 -1.33781784]]

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (16512, 8)
# (4128, 8)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (16512, 8)
# (4128, 8)
# (16512,)
# (4128,)

# %% [markdown]
# ## Model 1: Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
print(y_pred[:10])
# Out:
# [0.71912284 1.76401657 2.70965883 2.83892593 2.60465725 2.01175367
#  2.64550005 2.16875532 2.74074644 3.91561473]

# %%
print(y_test[:10])
# Out:
# 20046    0.47700
# 3024     0.45800
# 15663    5.00001
# 20484    2.18600
# 9814     2.78000
# 13311    1.58700
# 7113     1.98200
# 7668     1.57500
# 18246    3.40000
# 5723     4.46600
# Name: HousePrice, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
import numpy as np

rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("RMSE:", rmse)
# Out:
# RMSE: 0.7455813830127763

# %%
r2 = r2_score(y_test, y_pred)

print("R2 Score:", r2)
# Out:
# R2 Score: 0.5757877060324508

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.scatter(y_test, y_pred, alpha=0.5)

plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")

plt.title("Actual vs Predicted House Prices")

plt.show()

# %% [markdown]
# ## Model 2: Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha=1.0)

# %%
ridge_model.fit(X_train, y_train)
# Out:
# Ridge()

# %%
ridge_pred = ridge_model.predict(X_test)

# %%
ridge_rmse = np.sqrt(
    mean_squared_error(
        y_test,
        ridge_pred
    )
)

print(ridge_rmse)
# Out:
# 0.7455542909384609

# %%
ridge_r2 = r2_score(
    y_test,
    ridge_pred
)

print(ridge_r2)
# Out:
# 0.5758185345441322

# %% [markdown]
# ## Model 3: Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree_model = DecisionTreeRegressor(
    max_depth=5,
    random_state=42
)

# %%
tree_model.fit(
    X_train,
    y_train
)
# Out:
# DecisionTreeRegressor(max_depth=5, random_state=42)

# %%
tree_pred = tree_model.predict(
    X_test
)

# %%
tree_rmse = np.sqrt(
    mean_squared_error(
        y_test,
        tree_pred
    )
)

print(tree_rmse)
# Out:
# 0.7242338143386247

# %%
tree_r2 = r2_score(
    y_test,
    tree_pred
)

print(tree_r2)
# Out:
# 0.5997321244428706

# %% [markdown]
# ## Model Evaluation

# %%
import pandas as pd

results = pd.DataFrame({
    "Model":[
        "Linear Regression",
        "Ridge Regression",
        "Decision Tree"
    ],

    "RMSE":[
        rmse,
        ridge_rmse,
        tree_rmse
    ],

    "R2 Score":[
        r2,
        ridge_r2,
        tree_r2
    ]
})

results
# Out:
#                Model      RMSE  R2 Score
# 0  Linear Regression  0.745581  0.575788
# 1   Ridge Regression  0.745554  0.575819
# 2      Decision Tree  0.724234  0.599732

# %%
from sklearn.linear_model import Ridge

ridge_model = Ridge(alpha=1.0)

ridge_model.fit(X_train, y_train)

ridge_pred = ridge_model.predict(X_test)

# %%
ridge_rmse = np.sqrt(mean_squared_error(y_test, ridge_pred))

ridge_r2 = r2_score(y_test, ridge_pred)

print("Ridge RMSE:", ridge_rmse)
print("Ridge R2:", ridge_r2)
# Out:
# Ridge RMSE: 0.7455542909384609
# Ridge R2: 0.5758185345441322

# %%
from sklearn.tree import DecisionTreeRegressor

tree_model = DecisionTreeRegressor(
    max_depth=5,
    random_state=42
)

tree_model.fit(X_train, y_train)

tree_pred = tree_model.predict(X_test)

# %%
tree_rmse = np.sqrt(mean_squared_error(y_test, tree_pred))

tree_r2 = r2_score(y_test, tree_pred)

print("Tree RMSE:", tree_rmse)
print("Tree R2:", tree_r2)
# Out:
# Tree RMSE: 0.7242338143386247
# Tree R2: 0.5997321244428706

# %%
results = pd.DataFrame({
    "Model": [
        "Linear Regression",
        "Ridge Regression",
        "Decision Tree"
    ],
    "RMSE": [
        rmse,
        ridge_rmse,
        tree_rmse
    ],
    "R2 Score": [
        r2,
        ridge_r2,
        tree_r2
    ]
})

results
# Out:
#                Model      RMSE  R2 Score
# 0  Linear Regression  0.745581  0.575788
# 1   Ridge Regression  0.745554  0.575819
# 2      Decision Tree  0.724234  0.599732

# %% [markdown]
# ## Model Comparison

# %%
import matplotlib.pyplot as plt

models = ["Linear", "Ridge", "Decision Tree"]
r2_scores = [r2, ridge_r2, tree_r2]

plt.figure(figsize=(8,5))
plt.bar(models, r2_scores)

plt.title("R2 Score Comparison")
plt.xlabel("Models")
plt.ylabel("R2 Score")

plt.show()

# %%
models = ["Linear", "Ridge", "Decision Tree"]
rmse_scores = [rmse, ridge_rmse, tree_rmse]

plt.figure(figsize=(8,5))
plt.bar(models, rmse_scores)

plt.title("RMSE Comparison")
plt.xlabel("Models")
plt.ylabel("RMSE")

plt.show()

# %% [markdown]
# ### Observation
#
# Decision Tree Regressor achieved the highest R² score and the lowest RMSE, making it the best-performing model among the three models tested.

# %% [markdown]
# ## Feature Importance Analysis

# %%
feature_importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": tree_model.feature_importances_
})

feature_importance.sort_values(
    by="Importance",
    ascending=False
)
# Out:
#       Feature  Importance
# 0      MedInc    0.771212
# 5    AveOccup    0.128407
# 1    HouseAge    0.041621
# 2    AveRooms    0.031261
# 6    Latitude    0.022049
# 4  Population    0.002485
# 7   Longitude    0.002097
# 3   AveBedrms    0.000869

# %%
feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

plt.figure(figsize=(10,5))

plt.bar(
    feature_importance["Feature"],
    feature_importance["Importance"]
)

plt.title("Feature Importance")
plt.xlabel("Features")
plt.ylabel("Importance")

plt.show()

# %% [markdown]
# ### Observation
#
# Median Income was identified as the most important feature for predicting house prices. Other features contributed less significantly to the model's predictions.

# %% [markdown]
# ## Conclusion
#
# Three machine learning models were trained and evaluated on the California Housing Dataset.
#
# Decision Tree Regressor achieved the best performance with:
#
# - RMSE = 0.7242
# - R² Score = 0.5997
#
# Therefore, Decision Tree Regressor was selected as the best model for house price prediction.

# %% [markdown]
# ## Future Improvements
#
# - Hyperparameter Tuning can be performed to improve model performance.
# - Additional feature engineering techniques can be applied.
# - More advanced models such as Random Forest and XGBoost can be explored.
